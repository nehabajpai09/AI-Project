# %%
import re

def extract_loan_details(text):
    # naive extraction (baseline)
    nums = list(map(int, re.findall(r'\d+', text)))

    if len(nums) >= 3:
        return {
            "principal": nums[0],
            "rate": nums[1],
            "tenure": nums[2]
        }

    return None
